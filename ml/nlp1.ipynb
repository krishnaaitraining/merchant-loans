# %%
# %pip install nltk
# !python3 -m nltk.downloader all
# %pip install spacy
# !python3 -m spacy download en_core_web_sm
# %pip  install gensim
# %pip install textblob
# Out:
# Requirement already satisfied: nltk in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# <frozen runpy>:128: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# Requirement already satisfied: spacy in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (3.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (75.6.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 19.8 MB/s eta 0:00:00a 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Requirement already satisfied: gensim in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: textblob in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download necessary NLTK resources
#nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = "Natural Language Processing is amazing. It allows machines to understand text."
new_text = """The Python language has several use cases in application development, including the following examples:

Server-side web development
Server-side web development includes the complex backend functions that websites perform to display information to the user. For example, websites must interact with databases, talk to other websites, and protect data when sending it over the network. 

Python is useful for writing server-side code because it offers many libraries that consist of prewritten code for complex backend functions. Developers also use a wide range of Python frameworks that provide all the necessary tools to build web applications faster and more easily. For example, developers can create the skeleton web application in seconds because they don’t need to write it from scratch. They can then test it using the framework’s testing tools, without depending on external testing tools."""

print("Sentence Tokenization:", sent_tokenize(new_text, language="english"))
print("Word Tokenization:", word_tokenize(new_text))
# Out:
# Sentence Tokenization: ['The Python language has several use cases in application development, including the following examples:\n\nServer-side web development\nServer-side web development includes the complex backend functions that websites perform to display information to the user.', 'For example, websites must interact with databases, talk to other websites, and protect data when sending it over the network.', 'Python is useful for writing server-side code because it offers many libraries that consist of prewritten code for complex backend functions.', 'Developers also use a wide range of Python frameworks that provide all the necessary tools to build web applications faster and more easily.', 'For example, developers can create the skeleton web application in seconds because they don’t need to write it from scratch.', 'They can then test it using the framework’s testing tools, without depending on external testing tools.']
# Word Tokenization: ['The', 'Python', 'language', 'has', 'several', 'use', 'cases', 'in', 'application', 'development', ',', 'including', 'the', 'following', 'examples', ':', 'Server-side', 'web', 'development', 'Server-side', 'web', 'development', 'includes', 'the', 'complex', 'backend', 'functions', 'that', 'websites', 'perform', 'to', 'display', 'information', 'to', 'the', 'user', '.', 'For', 'example', ',', 'websites', 'must', 'interact', 'with', 'databases', ',', 'talk', 'to', 'other', 'websites', ',', 'and', 'protect', 'data', 'when', 'sending', 'it', 'over', 'the', 'network', '.', 'Python', 'is', 'useful', 'for', 'writing', 'server-side', 'code', 'because', 'it', 'offers', 'many', 'libraries', 'that', 'consist', 'of', 'prewritten', 'code', 'for', 'complex', 'backend', 'functions', '.', 'Developers', 'also', 'use', 'a', 'wide', 'range', 'of', 'Python', 'frameworks', 'that', 'provide', 'all', 'the', 'necessary', 'tools', 'to', 'build', 'web', 'applications', 'faster', 'and', 'more', 'easily', '.', 'For', 'example', ',', 'developers', 'can', 'create', 'the', 'skeleton', 'web', 'application', 'in', 'seconds', 'because', 'they', 'don', '’', 't', 'need', 'to', 'write', 'it', 'from', 'scratch', '.', 'They', 'can', 'then', 'test', 'it', 'using', 'the', 'framework', '’', 's', 'testing', 'tools', ',', 'without', 'depending', 'on', 'external', 'testing', 'tools', '.']

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    return tokens

# Example usage
sample_text = "Natural Language Processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence."
processed_tokens = preprocess_text(new_text)
print(processed_tokens)
# Out:
# ['python', 'language', 'several', 'use', 'cases', 'application', 'development', 'including', 'following', 'examples', 'serverside', 'web', 'development', 'serverside', 'web', 'development', 'includes', 'complex', 'backend', 'functions', 'websites', 'perform', 'display', 'information', 'user', 'example', 'websites', 'must', 'interact', 'databases', 'talk', 'websites', 'protect', 'data', 'sending', 'network', 'python', 'useful', 'writing', 'serverside', 'code', 'offers', 'many', 'libraries', 'consist', 'prewritten', 'code', 'complex', 'backend', 'functions', 'developers', 'also', 'use', 'wide', 'range', 'python', 'frameworks', 'provide', 'necessary', 'tools', 'build', 'web', 'applications', 'faster', 'easily', 'example', 'developers', 'create', 'skeleton', 'web', 'application', 'seconds', 'dont', 'need', 'write', 'scratch', 'test', 'using', 'frameworks', 'testing', 'tools', 'without', 'depending', 'external', 'testing', 'tools']

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
text = "Natural Language Processing is amazing. It allows machines to understand text."
words = word_tokenize(new_text)
print(words)
filtered_words = [word for word in words if word.lower() not in stop_words]

print("Filtered Words:", filtered_words)
#processed_tokens = preprocess_text(filtered_words)
#print("Processed Words:", processed_tokens)
# Out:
# ['The', 'Python', 'language', 'has', 'several', 'use', 'cases', 'in', 'application', 'development', ',', 'including', 'the', 'following', 'examples', ':', 'Server-side', 'web', 'development', 'Server-side', 'web', 'development', 'includes', 'the', 'complex', 'backend', 'functions', 'that', 'websites', 'perform', 'to', 'display', 'information', 'to', 'the', 'user', '.', 'For', 'example', ',', 'websites', 'must', 'interact', 'with', 'databases', ',', 'talk', 'to', 'other', 'websites', ',', 'and', 'protect', 'data', 'when', 'sending', 'it', 'over', 'the', 'network', '.', 'Python', 'is', 'useful', 'for', 'writing', 'server-side', 'code', 'because', 'it', 'offers', 'many', 'libraries', 'that', 'consist', 'of', 'prewritten', 'code', 'for', 'complex', 'backend', 'functions', '.', 'Developers', 'also', 'use', 'a', 'wide', 'range', 'of', 'Python', 'frameworks', 'that', 'provide', 'all', 'the', 'necessary', 'tools', 'to', 'build', 'web', 'applications', 'faster', 'and', 'more', 'easily', '.', 'For', 'example', ',', 'developers', 'can', 'create', 'the', 'skeleton', 'web', 'application', 'in', 'seconds', 'because', 'they', 'don', '’', 't', 'need', 'to', 'write', 'it', 'from', 'scratch', '.', 'They', 'can', 'then', 'test', 'it', 'using', 'the', 'framework', '’', 's', 'testing', 'tools', ',', 'without', 'depending', 'on', 'external', 'testing', 'tools', '.']
# Filtered Words: ['Python', 'language', 'several', 'use', 'cases', 'application', 'development', ',', 'including', 'following', 'examples', ':', 'Server-side', 'web', 'development', 'Server-side', 'web', 'development', 'includes', 'complex', 'backend', 'functions', 'websites', 'perform', 'display', 'information', 'user', '.', 'example', ',', 'websites', 'must', 'interact', 'databases', ',', 'talk', 'websites', ',', 'protect', 'data', 'sending', 'network', '.', 'Python', 'useful', 'writing', 'server-side', 'code', 'offers', 'many', 'libraries', 'consist', 'prewritten', 'code', 'complex', 'backend', 'functions', '.', 'Developers', 'also', 'use', 'wide', 'range', 'Python', 'frameworks', 'provide', 'necessary', 'tools', 'build', 'web', 'applications', 'faster', 'easily', '.', 'example', ',', 'developers', 'create', 'skeleton', 'web', 'application', 'seconds', '’', 'need', 'write', 'scratch', '.', 'test', 'using', 'framework', '’', 'testing', 'tools', ',', 'without', 'depending', 'external', 'testing', 'tools', '.']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gopikrishnapinninti/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
print(processed_tokens)
words = processed_tokens#["running", "flies", "easily", "fairly"]
print([ps.stem(word) for word in words])
# Out:
# ['python', 'language', 'several', 'use', 'cases', 'application', 'development', 'including', 'following', 'examples', 'serverside', 'web', 'development', 'serverside', 'web', 'development', 'includes', 'complex', 'backend', 'functions', 'websites', 'perform', 'display', 'information', 'user', 'example', 'websites', 'must', 'interact', 'databases', 'talk', 'websites', 'protect', 'data', 'sending', 'network', 'python', 'useful', 'writing', 'serverside', 'code', 'offers', 'many', 'libraries', 'consist', 'prewritten', 'code', 'complex', 'backend', 'functions', 'developers', 'also', 'use', 'wide', 'range', 'python', 'frameworks', 'provide', 'necessary', 'tools', 'build', 'web', 'applications', 'faster', 'easily', 'example', 'developers', 'create', 'skeleton', 'web', 'application', 'seconds', 'dont', 'need', 'write', 'scratch', 'test', 'using', 'frameworks', 'testing', 'tools', 'without', 'depending', 'external', 'testing', 'tools']
# ['python', 'languag', 'sever', 'use', 'case', 'applic', 'develop', 'includ', 'follow', 'exampl', 'serversid', 'web', 'develop', 'serversid', 'web', 'develop', 'includ', 'complex', 'backend', 'function', 'websit', 'perform', 'display', 'inform', 'user', 'exampl', 'websit', 'must', 'interact', 'databas', 'talk', 'websit', 'protect', 'data', 'send', 'network', 'python', 'use', 'write', 'serversid', 'code', 'offer', 'mani', 'librari', 'consist', 'prewritten', 'code', 'complex', 'backend', 'function', 'develop', 'also', 'use', 'wide', 'rang', 'python', 'framework', 'provid', 'necessari', 'tool', 'build', 'web', 'applic', 'faster', 'easili', 'exampl', 'develop', 'creat', 'skeleton', 'web', 'applic', 'second', 'dont', 'need', 'write', 'scratch', 'test', 'use', 'framework', 'test', 'tool', 'without', 'depend', 'extern', 'test', 'tool']

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

input_string = """The Python language has several use cases in application development, including the following examples:

Server-side web development
Server-side web development includes the complex backend functions that websites perform to display information to the user. For example, websites must interact with databases, talk to other websites, and protect data when sending it over the network. 

Python is useful for writing server-side code because it offers many libraries that consist of prewritten code for complex backend functions. Developers also use a wide range of Python frameworks that provide all the necessary tools to build web applications faster and more easily. For example, developers can create the skeleton web application in seconds because they don’t need to write it from scratch. They can then test it using the framework’s testing tools, without depending on external testing tools."""

doc = nlp(input_string) #"running flies easily fairly")
print([ps.stem(word) for word in words])
print([token.lemma_ for token in doc])
# Out:
# ['python', 'languag', 'sever', 'use', 'case', 'applic', 'develop', 'includ', 'follow', 'exampl', 'serversid', 'web', 'develop', 'serversid', 'web', 'develop', 'includ', 'complex', 'backend', 'function', 'websit', 'perform', 'display', 'inform', 'user', 'exampl', 'websit', 'must', 'interact', 'databas', 'talk', 'websit', 'protect', 'data', 'send', 'network', 'python', 'use', 'write', 'serversid', 'code', 'offer', 'mani', 'librari', 'consist', 'prewritten', 'code', 'complex', 'backend', 'function', 'develop', 'also', 'use', 'wide', 'rang', 'python', 'framework', 'provid', 'necessari', 'tool', 'build', 'web', 'applic', 'faster', 'easili', 'exampl', 'develop', 'creat', 'skeleton', 'web', 'applic', 'second', 'dont', 'need', 'write', 'scratch', 'test', 'use', 'framework', 'test', 'tool', 'without', 'depend', 'extern', 'test', 'tool']
# ['the', 'Python', 'language', 'have', 'several', 'use', 'case', 'in', 'application', 'development', ',', 'include', 'the', 'follow', 'example', ':', '\n\n', 'server', '-', 'side', 'web', 'development', '\n', 'Server', '-', 'side', 'web', 'development', 'include', 'the', 'complex', 'backend', 'function', 'that', 'website', 'perform', 'to', 'display', 'information', 'to', 'the', 'user', '.', 'for', 'example', ',', 'website', 'must', 'interact', 'with', 'database', ',', 'talk', 'to', 'other', 'website', ',', 'and', 'protect', 'datum', 'when', 'send', 'it', 'over', 'the', 'network', '.', '\n\n', 'Python', 'be', 'useful', 'for', 'write', 'server', '-', 'side', 'code', 'because', 'it', 'offer', 'many', 'library', 'that', 'consist', 'of', 'prewritten', 'code', 'for', 'complex', 'backend', 'function', '.', 'developer', 'also', 'use', 'a', 'wide', 'range', 'of', 'Python', 'framework', 'that', 'provide', 'all', 'the', 'necessary', 'tool', 'to', 'build', 'web', 'application', 'fast', 'and', 'more', 'easily', '.', 'for', 'example', ',', 'developer', 'can', 'create', 'the', 'skeleton', 'web', 'application', 'in', 'second', 'because', 'they', 'do', 'not', 'need', 'to', 'write', 'it', 'from', 'scratch', '.', 'they', 'can', 'then', 'test', 'it', 'use', 'the', 'framework', '’s', 'testing', 'tool', ',', 'without', 'depend', 'on', 'external', 'testing', 'tool', '.']

# %%
# import these modules
from nltk.stem import WordNetLemmatizer
 
lemmatizer = WordNetLemmatizer()
 
print("rocks :", lemmatizer.lemmatize("rocks"))
print("corpora :", lemmatizer.lemmatize("corpora"))
 
# a denotes adjective in "pos"
print("better :", lemmatizer.lemmatize("better", pos="a"))
# Out:
# rocks : rock
# corpora : corpus
# better : good

# %%
doc = nlp("running flies easily fairly")
print([token.lemma_ for token in doc])

print(lemmatizer.lemmatize("running"))
print(lemmatizer.lemmatize("flies"))
print(lemmatizer.lemmatize("easily"))
print(lemmatizer.lemmatize("fairly"))
# Out:
# ['run', 'fly', 'easily', 'fairly']
# running
# fly
# easily
# fairly

# %%
#Bag of Words : BoW represents text as a matrix of word occurrences. It discards the order of words and focuses on the occurrence of words in the text.

from sklearn.feature_extraction.text import CountVectorizer

corpus = ["Natural Language Processing is fun!", "I love learning NLP."]
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)

print("Vocabulary:", vectorizer.get_feature_names_out())
print("BoW Representation:\n", X.toarray())
# Out:
# Vocabulary: ['fun' 'is' 'language' 'learning' 'love' 'natural' 'nlp' 'processing']
# BoW Representation:
#  [[1 1 1 0 0 1 0 1]
#  [0 0 0 1 1 0 1 0]]

# %%
#Term Frequency-Inverse Document Frequency (TF-IDF) : TF-IDF is a statistical measure used to evaluate the importance of a word in a document relative to a collection of documents. It is a product of two terms: Term Frequency (TF) and Inverse Document Frequency (IDF).
#Word Embeddings : Word embeddings are dense vector representations of words in a high-dimensional space. They capture the semantic meaning of words and their relationships with other words.
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names_out())
print("TF-IDF Representation:\n", X.toarray())
# Out:
# ['fun' 'is' 'language' 'learning' 'love' 'natural' 'nlp' 'processing']
# TF-IDF Representation:
#  [[0.4472136  0.4472136  0.4472136  0.         0.         0.4472136
#   0.         0.4472136 ]
#  [0.         0.         0.         0.57735027 0.57735027 0.
#   0.57735027 0.        ]]

# %%
from gensim.models import Word2Vec

# Tokenized sentences
sentences = [
["natural", "language", "processing", "fascinating"],
["love", "working", "text", "data"],
["machine", "learning", "models", "understand", "text"]
]
# Train Word2Vec model
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, sg=0)

# Get vector for a word
vector = model.wv['text']
print(vector[:5]) # Print first 5 dimensions

# Find similar words
similar_words = model.wv.most_similar('text', topn=3)
print(similar_words)
# Out:
# [-0.00053623  0.00023643  0.00510335  0.00900927 -0.00930295]
# [('processing', 0.21617142856121063), ('love', 0.09291722625494003), ('natural', 0.0796348825097084)]

# %%
from textblob import TextBlob

text = "The film follows the life of Alabama native Forest Gump, a good man with an ideally low IQ of 75, as historical events occur through his eyes. Jenny Curran was one of Forrest Gump’s few childhood friends and his first and only romantic interest. Throughout the film, Gump regularly experiences adversity but never loses his positive outlook. He may have been physically impaired, but he always retained sight of the big picture. He overcame adversity with his mother’s support and received a football scholarship."
sentiment = TextBlob(text).sentiment
print("Polarity:", sentiment.polarity)
# Out:
# Polarity: 0.09393939393939393

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Barack Obama was born in Hawaii and was the President of the USA.")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Barack Obama PERSON
# Hawaii GPE
# USA GPE

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer

X = ["Win a free iPhone now!", "Meeting at 5 PM", "Exclusive offer just for you"]
y = ["spam", "ham", "spam"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

pipeline = Pipeline([('vectorizer', CountVectorizer()),('classifier', MultinomialNB())])

pipeline.fit(X_train, y_train)
print("Prediction:", pipeline.predict(["Get your free gift now!"]))
# Out:
# Prediction: ['ham']

# %%
newsarticle = """Vice President JD Vance defended President Donald Trump and his administration’s foreign policy agenda Friday during a tense exchange with Ukrainian President Volodymyr Zelenskyy — inserting himself into a spotlight rarely seen by vice presidents. 

Trump and Vance sparred in the Oval Office Friday with Zelenskyy amid negotiations to end the war in Ukraine — an exchange that ultimately prompted Trump to announce an end to peace negotiations and request that the Ukrainian leader leave the White House. 

A source familiar with the meeting told Fox News Digital that there was no expectation of the meeting leading to a combative exchange, and that Trump and Vance were both caught off guard by Zelenskyy’s behavior. 


While vice presidents traditionally remain in the wings while the president takes center stage, Friday's encounter with Zelenskyy exposed the weight Vance carries directing and advancing the Trump administration's America First agenda — both at home and abroad.

"""
#doc = nlp("Barack Obama was born in Hawaii and was the President of the USA.")
doc = nlp(newsarticle)
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# JD Vance PERSON
# Donald Trump PERSON
# Friday DATE
# Ukrainian NORP
# Volodymyr Zelenskyy PERSON
# Trump ORG
# Vance PERSON
# the Oval Office ORG
# Friday DATE
# Zelenskyy ORG
# Ukraine GPE
# Trump ORG
# Ukrainian NORP
# the White House ORG
# Fox News Digital ORG
# Trump PERSON
# Vance PERSON
# Zelenskyy ORG
# Friday DATE
# Zelenskyy ORG
# Vance PERSON
# Trump PERSON
# America GPE
# First ORDINAL
