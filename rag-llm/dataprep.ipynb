# %%
# !pip3 install datasets
# Out:
# Requirement already satisfied: datasets in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (3.3.2)
# Requirement already satisfied: filelock in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (3.11.12)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (0.29.3)
# Requirement already satisfied: packaging in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/gopikrishnapinninti/development/projects/finbloom/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from datasets import load_dataset
import pandas as pd
# <https://huggingface.co/datasets/AIatMongoDB/embedded_movies>
dataset = load_dataset("AIatMongoDB/embedded_movies")
# Convert the dataset to a pandas dataframe
dataset_df = pd.DataFrame(dataset['train'])
dataset_df.head(5)
# Out:
#                                                 plot  \
# 0  Young Pauline is left a lot of money when her ...
# 1  A penniless young man tries to save an heiress...
# 2  Michael "Beau" Geste leaves England in disgrac...
# 3  Seeking revenge, an athletic young man joins t...
# 4  An irresponsible young millionaire changes his...
#
#                        genres  runtime  \
# 0                    [Action]    199.0
# 1     [Comedy, Short, Action]     22.0
# 2  [Action, Adventure, Drama]    101.0
# 3         [Adventure, Action]     88.0
# 4   [Action, Comedy, Romance]     58.0
#
#                                                 cast  num_mflix_comments  \
# 0  [Pearl White, Crane Wilbur, Paul Panzer, Edwar...                   0
# 1  [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...                   0
# 2  [Ronald Colman, Neil Hamilton, Ralph Forbes, A...                   0
# 3  [Billie Dove, Tempe Pigott, Donald Crisp, Sam ...                   1
# 4  [Harold Lloyd, Jobyna Ralston, Noah Young, Jim...                   0
#
#                                               poster                  title  \
# 0  https://m.media-amazon.com/images/M/MV5BMzgxOD...  The Perils of Pauline
# 1  https://m.media-amazon.com/images/M/MV5BNzE1OW...     From Hand to Mouth
# 2                                               None             Beau Geste
# 3  https://m.media-amazon.com/images/M/MV5BMzU0ND...       The Black Pirate
# 4  https://m.media-amazon.com/images/M/MV5BMTcxMT...      For Heaven's Sake
#
#                                             fullplot  languages  \
# 0  Young Pauline is left a lot of money when her ...  [English]
# 1  As a penniless man worries about how he will m...  [English]
# 2  Michael "Beau" Geste leaves England in disgrac...  [English]
# 3  A nobleman vows to avenge the death of his fat...       None
# 4  The Uptown Boy, J. Harold Manners (Lloyd) is a...  [English]
#
#                               directors  \
# 0  [Louis J. Gasnier, Donald MacKenzie]
# 1       [Alfred J. Goulding, Hal Roach]
# 2                      [Herbert Brenon]
# 3                       [Albert Parker]
# 4                          [Sam Taylor]
#
#                                              writers  \
# 0  [Charles W. Goddard (screenplay), Basil Dickey...
# 1                             [H.M. Walker (titles)]
# 2  [Herbert Brenon (adaptation), John Russell (ad...
# 3  [Douglas Fairbanks (story), Jack Cunningham (a...
# 4  [Ted Wilde (story), John Grey (story), Clyde B...
#
#                                               awards  \
# 0    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 1  {'nominations': 1, 'text': '1 nomination.', 'w...
# 2    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 3    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 4  {'nominations': 1, 'text': '1 nomination.', 'w...
#
#                                           imdb countries   type  \
# 0    {'id': 4465, 'rating': 7.6, 'votes': 744}     [USA]  movie
# 1   {'id': 10146, 'rating': 7.0, 'votes': 639}     [USA]  movie
# 2   {'id': 16634, 'rating': 6.9, 'votes': 222}     [USA]  movie
# 3  {'id': 16654, 'rating': 7.2, 'votes': 1146}     [USA]  movie
# 4   {'id': 16895, 'rating': 7.6, 'votes': 918}     [USA]  movie
#
#                                       plot_embedding   rated  metacritic
# 0  [0.0007293965299999999, -0.026834568000000003,...    None         NaN
# 1  [-0.022837115, -0.022941574000000003, 0.014937...    TV-G         NaN
# 2  [0.00023330492999999998, -0.028511643000000003...    None         NaN
# 3  [-0.005927917, -0.033394486, 0.0015323418, -0....    None         NaN
# 4  [-0.0059373598, -0.026604708, -0.0070914757000...  PASSED         NaN

# %%
# Remove data point where plot column is missing
dataset_df = dataset_df.dropna(subset=['plot'])
print("\\nNumber of missing values in each column after removal:")
print(dataset_df.isnull().sum())

# Remove the plot_embedding from each data point in the dataset as we are going to create new embeddings with the new OpenAI embedding Model "text-embedding-3-small"
dataset_df = dataset_df.drop(columns=['plot_embedding'])
dataset_df.head(5)
# Out:
# \nNumber of missing values in each column after removal:
# plot                    0
# genres                  0
# runtime                14
# cast                    1
# num_mflix_comments      0
# poster                 78
# title                   0
# fullplot               21
# languages               1
# directors              13
# writers                13
# awards                  0
# imdb                    0
# countries               0
# type                    0
# plot_embedding          1
# rated                 284
# metacritic            903
# dtype: int64
#                                                 plot  \
# 0  Young Pauline is left a lot of money when her ...
# 1  A penniless young man tries to save an heiress...
# 2  Michael "Beau" Geste leaves England in disgrac...
# 3  Seeking revenge, an athletic young man joins t...
# 4  An irresponsible young millionaire changes his...
#
#                        genres  runtime  \
# 0                    [Action]    199.0
# 1     [Comedy, Short, Action]     22.0
# 2  [Action, Adventure, Drama]    101.0
# 3         [Adventure, Action]     88.0
# 4   [Action, Comedy, Romance]     58.0
#
#                                                 cast  num_mflix_comments  \
# 0  [Pearl White, Crane Wilbur, Paul Panzer, Edwar...                   0
# 1  [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...                   0
# 2  [Ronald Colman, Neil Hamilton, Ralph Forbes, A...                   0
# 3  [Billie Dove, Tempe Pigott, Donald Crisp, Sam ...                   1
# 4  [Harold Lloyd, Jobyna Ralston, Noah Young, Jim...                   0
#
#                                               poster                  title  \
# 0  https://m.media-amazon.com/images/M/MV5BMzgxOD...  The Perils of Pauline
# 1  https://m.media-amazon.com/images/M/MV5BNzE1OW...     From Hand to Mouth
# 2                                               None             Beau Geste
# 3  https://m.media-amazon.com/images/M/MV5BMzU0ND...       The Black Pirate
# 4  https://m.media-amazon.com/images/M/MV5BMTcxMT...      For Heaven's Sake
#
#                                             fullplot  languages  \
# 0  Young Pauline is left a lot of money when her ...  [English]
# 1  As a penniless man worries about how he will m...  [English]
# 2  Michael "Beau" Geste leaves England in disgrac...  [English]
# 3  A nobleman vows to avenge the death of his fat...       None
# 4  The Uptown Boy, J. Harold Manners (Lloyd) is a...  [English]
#
#                               directors  \
# 0  [Louis J. Gasnier, Donald MacKenzie]
# 1       [Alfred J. Goulding, Hal Roach]
# 2                      [Herbert Brenon]
# 3                       [Albert Parker]
# 4                          [Sam Taylor]
#
#                                              writers  \
# 0  [Charles W. Goddard (screenplay), Basil Dickey...
# 1                             [H.M. Walker (titles)]
# 2  [Herbert Brenon (adaptation), John Russell (ad...
# 3  [Douglas Fairbanks (story), Jack Cunningham (a...
# 4  [Ted Wilde (story), John Grey (story), Clyde B...
#
#                                               awards  \
# 0    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 1  {'nominations': 1, 'text': '1 nomination.', 'w...
# 2    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 3    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 4  {'nominations': 1, 'text': '1 nomination.', 'w...
#
#                                           imdb countries   type   rated  \
# 0    {'id': 4465, 'rating': 7.6, 'votes': 744}     [USA]  movie    None
# 1   {'id': 10146, 'rating': 7.0, 'votes': 639}     [USA]  movie    TV-G
# 2   {'id': 16634, 'rating': 6.9, 'votes': 222}     [USA]  movie    None
# 3  {'id': 16654, 'rating': 7.2, 'votes': 1146}     [USA]  movie    None
# 4   {'id': 16895, 'rating': 7.6, 'votes': 918}     [USA]  movie  PASSED
#
#    metacritic
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv  
load_dotenv()


# Initialize Pinecone client
print(os.getenv("OPENAI_API_KEY"))
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

EMBEDDING_MODEL = "text-embedding-3-small"

def get_embedding(text):
    """Generate an embedding for the given text using OpenAI's API."""

    # Check for valid input
    if not text or not isinstance(text, str):
        return None

    try:
        # Call OpenAI API to get the embedding
        embedding = client.embeddings.create(input=text, model=EMBEDDING_MODEL).data[0].embedding
        return embedding
    except Exception as e:
        print(f"Error in get_embedding: {e}")
        return None
# Out:
# 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

# %%
dataset_df["plot_embedding_optimised"] = dataset_df['plot'].apply(get_embedding)

dataset_df.head()
# Out:
#                                                 plot  \
# 0  Young Pauline is left a lot of money when her ...
# 1  A penniless young man tries to save an heiress...
# 2  Michael "Beau" Geste leaves England in disgrac...
# 3  Seeking revenge, an athletic young man joins t...
# 4  An irresponsible young millionaire changes his...
#
#                        genres  runtime  \
# 0                    [Action]    199.0
# 1     [Comedy, Short, Action]     22.0
# 2  [Action, Adventure, Drama]    101.0
# 3         [Adventure, Action]     88.0
# 4   [Action, Comedy, Romance]     58.0
#
#                                                 cast  num_mflix_comments  \
# 0  [Pearl White, Crane Wilbur, Paul Panzer, Edwar...                   0
# 1  [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...                   0
# 2  [Ronald Colman, Neil Hamilton, Ralph Forbes, A...                   0
# 3  [Billie Dove, Tempe Pigott, Donald Crisp, Sam ...                   1
# 4  [Harold Lloyd, Jobyna Ralston, Noah Young, Jim...                   0
#
#                                               poster                  title  \
# 0  https://m.media-amazon.com/images/M/MV5BMzgxOD...  The Perils of Pauline
# 1  https://m.media-amazon.com/images/M/MV5BNzE1OW...     From Hand to Mouth
# 2                                               None             Beau Geste
# 3  https://m.media-amazon.com/images/M/MV5BMzU0ND...       The Black Pirate
# 4  https://m.media-amazon.com/images/M/MV5BMTcxMT...      For Heaven's Sake
#
#                                             fullplot  languages  \
# 0  Young Pauline is left a lot of money when her ...  [English]
# 1  As a penniless man worries about how he will m...  [English]
# 2  Michael "Beau" Geste leaves England in disgrac...  [English]
# 3  A nobleman vows to avenge the death of his fat...       None
# 4  The Uptown Boy, J. Harold Manners (Lloyd) is a...  [English]
#
#                               directors  \
# 0  [Louis J. Gasnier, Donald MacKenzie]
# 1       [Alfred J. Goulding, Hal Roach]
# 2                      [Herbert Brenon]
# 3                       [Albert Parker]
# 4                          [Sam Taylor]
#
#                                              writers  \
# 0  [Charles W. Goddard (screenplay), Basil Dickey...
# 1                             [H.M. Walker (titles)]
# 2  [Herbert Brenon (adaptation), John Russell (ad...
# 3  [Douglas Fairbanks (story), Jack Cunningham (a...
# 4  [Ted Wilde (story), John Grey (story), Clyde B...
#
#                                               awards  \
# 0    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 1  {'nominations': 1, 'text': '1 nomination.', 'w...
# 2    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 3    {'nominations': 0, 'text': '1 win.', 'wins': 1}
# 4  {'nominations': 1, 'text': '1 nomination.', 'w...
#
#                                           imdb countries   type   rated  \
# 0    {'id': 4465, 'rating': 7.6, 'votes': 744}     [USA]  movie    None
# 1   {'id': 10146, 'rating': 7.0, 'votes': 639}     [USA]  movie    TV-G
# 2   {'id': 16634, 'rating': 6.9, 'votes': 222}     [USA]  movie    None
# 3  {'id': 16654, 'rating': 7.2, 'votes': 1146}     [USA]  movie    None
# 4   {'id': 16895, 'rating': 7.6, 'votes': 918}     [USA]  movie  PASSED
#
#    metacritic                           plot_embedding_optimised
# 0         NaN  [0.015450738370418549, -0.0037871389649808407,...
# 1         NaN  [-0.024403288960456848, 0.009791935794055462, ...
# 2         NaN  [-0.03142419457435608, 0.07591885328292847, 0....
# 3         NaN  [0.021738531067967415, 0.06848915666341782, 0....
# 4         NaN  [0.008178990334272385, -0.019387762993574142, ...

# %%
dataset_df.to_csv('allmovies.csv')

# %%
import pymongo
import pandas as pd


dataset_df_new = pd.read_csv('allmovies.csv')
def get_mongo_client(mongo_uri):
  """Establish connection to the MongoDB."""
  try:
    client = pymongo.MongoClient(mongo_uri)
    print("Connection to MongoDB successful")
    return client
  except pymongo.errors.ConnectionFailure as e:
    print(f"Connection failed: {e}")
    return None

mongo_uri = os.getenv('MONGO_DB_CONNECTION')
if not mongo_uri:
  print("MONGO_URI not set in environment variables")

mongo_client = get_mongo_client(mongo_uri)

# Ingest data into MongoDB
db = mongo_client['movies']
collection = db['movie_collection'] 

documents = dataset_df.to_dict('records')
collection.insert_many(documents)

print("Data ingestion into MongoDB completed")
# Out:
# Connection to MongoDB successful
# Data ingestion into MongoDB completed

# %%
def vector_search(user_query, collection):
    """
    Perform a vector search in the MongoDB collection based on the user query.

    Args:
    user_query (str): The user's query string.
    collection (MongoCollection): The MongoDB collection to search.

    Returns:
    list: A list of matching documents.
    """

    # Generate embedding for the user query
    query_embedding = get_embedding(user_query)

    if query_embedding is None:
        return "Invalid query or embedding generation failed."

    # Define the vector search pipeline
    pipeline = [
        {
            "$vectorSearch": {
                "index": "vector_index",
                "queryVector": query_embedding,
                "path": "plot_embedding_optimised",
                "numCandidates": 150,  # Number of candidate matches to consider
                "limit": 5  # Return top 5 matches
            }
        }
    ]

    # Execute the search
    results = collection.aggregate(pipeline)
    #results = collection.find({}, {title: 1, body:1, category:1, likes:1, tags:1})
    return list(results)

# %%
def handle_user_query(query, collection):

  get_knowledge = vector_search(query, collection)

  search_result = ''
  for result in get_knowledge:
      search_result += f"Title: {result.get('title', 'N/A')}, Plot: {result.get('plot', 'N/A')}\\n"

  completion = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
          {"role": "system", "content": "You are a movie recommendation system."},
          {"role": "user", "content": "Answer this user query: " + query + " with the following context: " + search_result}
      ]
  )

  return (completion.choices[0].message.content), search_result

#Conduct query with retrieval of sources
query = "What is the best romantic movie to watch?"
response, source_information = handle_user_query(query, collection)

print(f"Response: {response}")
print(f"Source Information: \\n{source_information}")
# Out:
# Response: Based on the context provided, I would recommend the movie "Gorgeous" for a romantic film to watch. It follows a romantic girl who travels to Hong Kong in search of love but ends up falling for a kind-hearted professional fighter. The plot of love blossoming unexpectedly makes it a great choice for a romantic movie night.
# Source Information: \nTitle: Run, Plot: This action movie is filled with romance and adventure. As Abhisek fights for his life against the forces of crime and injustice, he meets Bhoomika, who captures his heart.\nTitle: China Girl, Plot: A modern day Romeo & Juliet story is told in New York when an Italian boy and a Chinese girl become lovers, causing a tragic conflict between ethnic gangs.\nTitle: Gorgeous, Plot: A romantic girl travels to Hong Kong in search of certain love but instead meets a kind-hearted professional fighter with whom she begins to fall for instead.\nTitle: Once a Thief, Plot: A romantic and action packed story of three best friends, a group of high end art thieves, who come into trouble when a love-triangle forms between them.\nTitle: House of Flying Daggers, Plot: A romantic police captain breaks a beautiful member of a rebel group out of prison to help her rejoin her fellows, but things are not what they seem.\n
